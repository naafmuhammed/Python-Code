# %%
# !pip install pandas openpyxl

# %%
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')

# %%
print(df.head())
# Out:
#             Name            Team  Number Position  Age               Height  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1    Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2   John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3    R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
#
#    Weight            College     Salary
# 0     180              Texas  7730337.0
# 1     235          Marquette  6796117.0
# 2     205  Boston University        NaN
# 3     185      Georgia State  1148640.0
# 4     231                NaN  5000000.0

# %%
print(df.columns)
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
print(df.describe())
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.to_excel('output.xlsx', index=False)

# %%
import pandas as pd

# %%
df.columns = df.columns.str.strip()

# %%
print("Columns in dataset:", df.columns.tolist())
# Out:
# Columns in dataset: ['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College', 'Salary']

# %%
print("✅ Team-wise distribution:")
# Out:
# ✅ Team-wise distribution:

# %%
print(team_distribution)
# Out:
#                         Employee Count  Percentage
# Team
# New Orleans Pelicans                19        4.15
# Memphis Grizzlies                   18        3.93
# Utah Jazz                           16        3.49
# New York Knicks                     16        3.49
# Milwaukee Bucks                     16        3.49
# Brooklyn Nets                       15        3.28
# Portland Trail Blazers              15        3.28
# Oklahoma City Thunder               15        3.28
# Denver Nuggets                      15        3.28
# Washington Wizards                  15        3.28
# Miami Heat                          15        3.28
# Charlotte Hornets                   15        3.28
# Atlanta Hawks                       15        3.28
# San Antonio Spurs                   15        3.28
# Houston Rockets                     15        3.28
# Boston Celtics                      15        3.28
# Indiana Pacers                      15        3.28
# ...

# %%
print("Available columns:", df.columns.tolist())
# Out:
# Available columns: ['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College', 'Salary']

# %%
position_column = 'Position'

# %%
position_counts = df[position_column].value_counts().reset_index()
position_counts.columns = ['Position', 'Employee Count']

# %%
print("✅ Employees segregated by position:")
# Out:
# ✅ Employees segregated by position:

# %%
print(position_counts)
# Out:
#   Position  Employee Count
# 0       SG             102
# 1       PF             100
# 2       PG              92
# 3       SF              85
# 4        C              79

# %%
print("Available columns:", df.columns.tolist())
# Out:
# Available columns: ['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College', 'Salary']

# %%
from datetime import datetime

# %%
today = pd.Timestamp.today()

# %%
if 'Team' in df.columns:
    
    team_counts = df['Team'].value_counts()

    
    team_percentage = (team_counts / team_counts.sum()) * 100

    
    team_distribution = pd.DataFrame({
        'Employee Count': team_counts,
        'Percentage': team_percentage.round(2)
    })

    print("Team-wise employee distribution:")
    print(team_distribution)

else:
    print("Column 'Team' not found in the dataset.")
# Out:
# Team-wise employee distribution:
#                         Employee Count  Percentage
# Team
# New Orleans Pelicans                19        4.15
# Memphis Grizzlies                   18        3.93
# Utah Jazz                           16        3.49
# New York Knicks                     16        3.49
# Milwaukee Bucks                     16        3.49
# Brooklyn Nets                       15        3.28
# Portland Trail Blazers              15        3.28
# Oklahoma City Thunder               15        3.28
# Denver Nuggets                      15        3.28
# Washington Wizards                  15        3.28
# Miami Heat                          15        3.28
# Charlotte Hornets                   15        3.28
# Atlanta Hawks                       15        3.28
# San Antonio Spurs                   15        3.28
# Houston Rockets                     15        3.28
# Boston Celtics                      15        3.28
# Indiana Pacers                      15        3.28
# ...

# %%
df.columns = df.columns.str.strip()

# %%
import pandas as pd

# %%
print(df.columns)
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df = pd.read_excel('data.xlsx')

# %%
df.columns = df.columns.str.strip()

# %%
print("Columns:", df.columns.tolist())
# Out:
# Columns: ['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College', 'Salary']

# %%
team_col = 'team'
position_col = 'position'
salary_col = 'salary'

# %%
print("✅ Team and Position with highest salary expenditure:")
# Out:
# ✅ Team and Position with highest salary expenditure:

# %%
df.columns = df.columns.str.strip()

# %%
df['age'] = (today - df['dob']).dt.days // 365
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dob'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 df['age'] = (today - df['dob']).dt.days // 365
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,5))
sns.histplot(df['height'], bins=15, kde=True, color='skyblue')
plt.title('Distribution of Corrected Heights')
plt.xlabel('Height (cm)')
plt.ylabel('Frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'height'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[86], line 5
#       2 import seaborn as sns
#       4 plt.figure(figsize=(8,5))
# ...

# %%
plt.figure(figsize=(8,5))
team_counts.plot(kind='bar', color='coral')
plt.title('Employee Distribution Across Teams')
plt.xlabel('Team')
plt.ylabel('Number of Employees')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, y='Position', order=df['Position'].value_counts().index, palette='viridis')
plt.title('Employee Count by Position')
plt.xlabel('Number of Employees')
plt.ylabel('Position')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\muhdp\AppData\Local\Temp\ipykernel_6036\72676665.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y='Position', order=df['Position'].value_counts().index, palette='viridis')

# %%
plt.figure(figsize=(8,5))
age_group_counts.plot(kind='bar', color='mediumseagreen')
plt.title('Employee Distribution by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Number of Employees')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 2
#       1 plt.figure(figsize=(8,5))
# ----> 2 age_group_counts.plot(kind='bar', color='mediumseagreen')
#       3 plt.title('Employee Distribution by Age Group')
#       4 plt.xlabel('Age Group')
#
# NameError: name 'age_group_counts' is not defined

# %%
plt.figure(figsize=(8,5))
sns.regplot(x='age', y='salary', data=df, scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title(f'Correlation Between Age and Salary (r = {df["age"].corr(df["salary"]):.2f})')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 2
#       1 plt.figure(figsize=(8,5))
# ...
